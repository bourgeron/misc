# %%
from utils import *

# %%
period = timedelta(days=730)  # 2 years

# %% [markdown]
# # Load symbols

# %%
path_simus = Path('./simus_with_more_shifts/')

paths_universes = (
    pl.scan_parquet(path_simus / 'index.parquet')
    .filter(pl.col('n_stocks') <= 100)
    .select('path')
    .collect()
)

symbols = [
    set(
        pl.scan_parquet(Path(path).parent / ('universe_' + Path(path).name))
        .select('symbol')
        .unique()
        .collect()
        .get_column('symbol')
        .to_list()
    )
    for path in paths_universes.get_column('path')
]
columns = sorted(set.union(*symbols))
len(columns)
# Out:
# 880

# %% [markdown]
# # Load returns

# %%
returns = (
    load_and_prepare_market_data(start_date=init_date - period)
    .with_columns(pl.col('price').pct_change().over(keys[1]).alias('return'))
    .filter(pl.col(keys[1]).is_in(columns))
    .collect()
    .pivot(index=keys[0], columns=keys[1], values='return', sort_columns=True)
    .sort('date')
)
dates = returns.get_column('date')
print(len(dates))
# Out:
# 6609

# %% [markdown]
# # Compute covariance for one day

# %%
# %%time
date = dates[1000]
name = date.strftime('%y%m%d') + '.parquet'
sub = (
    returns
    .filter(pl.col('date') <= date)
    .filter(pl.col('date') > date - period)
)
(
    shape_matrix(
        sub
        .select(pairs_cov(columns))
        .row(0),
        columns
    )
)
# Out:
# CPU times: user 4.02 s, sys: 961 ms, total: 4.98 s
# Wall time: 3.66 s
#       AACG  AAL  AAOI      AAPL  AAXJ      ABEO      ABIO  ABNB  ABTS  ABUS  \
# AACG   1.0 -0.0  -0.0 -0.000000  -0.0 -0.000000 -0.000000  -0.0  -0.0  -0.0
# AAL   -0.0  1.0  -0.0 -0.000000  -0.0 -0.000000 -0.000000  -0.0  -0.0  -0.0
# AAOI  -0.0 -0.0   1.0 -0.000000  -0.0 -0.000000 -0.000000  -0.0  -0.0  -0.0
# AAPL  -0.0 -0.0  -0.0  1.000000  -0.0  0.000067  0.000818  -0.0  -0.0  -0.0
# AAXJ  -0.0 -0.0  -0.0 -0.000000   1.0 -0.000000 -0.000000  -0.0  -0.0  -0.0
# ...    ...  ...   ...       ...   ...       ...       ...   ...   ...   ...
# ZI    -0.0 -0.0  -0.0 -0.000000  -0.0 -0.000000 -0.000000  -0.0  -0.0  -0.0
# ZION  -0.0 -0.0  -0.0  0.000166  -0.0 -0.000019  0.000245  -0.0  -0.0  -0.0
# ZM    -0.0 -0.0  -0.0 -0.000000  -0.0 -0.000000 -0.000000  -0.0  -0.0  -0.0
# ZS    -0.0 -0.0  -0.0 -0.000000  -0.0 -0.000000 -0.000000  -0.0  -0.0  -0.0
# ZUMZ  -0.0 -0.0  -0.0 -0.000000  -0.0 -0.000000 -0.000000  -0.0  -0.0  -0.0
#
#       ...   YY    Z      ZBRA        ZD   ZG   ZI      ZION   ZM   ZS  ZUMZ
# AACG  ... -0.0 -0.0 -0.000000 -0.000000 -0.0 -0.0 -0.000000 -0.0 -0.0  -0.0
# AAL   ... -0.0 -0.0 -0.000000 -0.000000 -0.0 -0.0 -0.000000 -0.0 -0.0  -0.0
# AAOI  ... -0.0 -0.0 -0.000000 -0.000000 -0.0 -0.0 -0.000000 -0.0 -0.0  -0.0
# AAPL  ... -0.0 -0.0  0.000558  0.000191 -0.0 -0.0  0.000166 -0.0 -0.0  -0.0
# AAXJ  ... -0.0 -0.0 -0.000000 -0.000000 -0.0 -0.0 -0.000000 -0.0 -0.0  -0.0
# ...   ...  ...  ...       ...       ...  ...  ...       ...  ...  ...   ...
# ZI    ... -0.0 -0.0 -0.000000 -0.000000 -0.0  1.0 -0.000000 -0.0 -0.0  -0.0
# ZION  ... -0.0 -0.0  0.000124 -0.000007 -0.0 -0.0  1.000000 -0.0 -0.0  -0.0
# ZM    ... -0.0 -0.0 -0.000000 -0.000000 -0.0 -0.0 -0.000000  1.0 -0.0  -0.0
# ZS    ... -0.0 -0.0 -0.000000 -0.000000 -0.0 -0.0 -0.000000 -0.0  1.0  -0.0
# ZUMZ  ... -0.0 -0.0 -0.000000 -0.000000 -0.0 -0.0 -0.000000 -0.0 -0.0   1.0
#
# [880 rows x 880 columns]

# %% [markdown]
# # Compute PCA

# %%
returns_pd = sub.to_pandas().set_index('date')

# %%
# %%time
returns_pd.cov()
# Out:
# CPU times: user 172 ms, sys: 0 ns, total: 172 ms
# Wall time: 171 ms
#       AACG  AAL  AAOI      AAPL  AAXJ      ABEO      ABIO  ABNB  ABTS  ABUS  \
# AACG   NaN  NaN   NaN       NaN   NaN       NaN       NaN   NaN   NaN   NaN
# AAL    NaN  NaN   NaN       NaN   NaN       NaN       NaN   NaN   NaN   NaN
# AAOI   NaN  NaN   NaN       NaN   NaN       NaN       NaN   NaN   NaN   NaN
# AAPL   NaN  NaN   NaN  0.002298   NaN  0.000067  0.000818   NaN   NaN   NaN
# AAXJ   NaN  NaN   NaN       NaN   NaN       NaN       NaN   NaN   NaN   NaN
# ...    ...  ...   ...       ...   ...       ...       ...   ...   ...   ...
# ZI     NaN  NaN   NaN       NaN   NaN       NaN       NaN   NaN   NaN   NaN
# ZION   NaN  NaN   NaN  0.000166   NaN -0.000019  0.000245   NaN   NaN   NaN
# ZM     NaN  NaN   NaN       NaN   NaN       NaN       NaN   NaN   NaN   NaN
# ZS     NaN  NaN   NaN       NaN   NaN       NaN       NaN   NaN   NaN   NaN
# ZUMZ   NaN  NaN   NaN       NaN   NaN       NaN       NaN   NaN   NaN   NaN
#
#       ...  YY   Z      ZBRA        ZD  ZG  ZI      ZION  ZM  ZS  ZUMZ
# AACG  ... NaN NaN       NaN       NaN NaN NaN       NaN NaN NaN   NaN
# AAL   ... NaN NaN       NaN       NaN NaN NaN       NaN NaN NaN   NaN
# AAOI  ... NaN NaN       NaN       NaN NaN NaN       NaN NaN NaN   NaN
# AAPL  ... NaN NaN  0.000558  0.000191 NaN NaN  0.000166 NaN NaN   NaN
# AAXJ  ... NaN NaN       NaN       NaN NaN NaN       NaN NaN NaN   NaN
# ...   ...  ..  ..       ...       ...  ..  ..       ...  ..  ..   ...
# ZI    ... NaN NaN       NaN       NaN NaN NaN       NaN NaN NaN   NaN
# ZION  ... NaN NaN  0.000124 -0.000007 NaN NaN  0.000666 NaN NaN   NaN
# ZM    ... NaN NaN       NaN       NaN NaN NaN       NaN NaN NaN   NaN
# ZS    ... NaN NaN       NaN       NaN NaN NaN       NaN NaN NaN   NaN
# ZUMZ  ... NaN NaN       NaN       NaN NaN NaN       NaN NaN NaN   NaN
#
# [880 rows x 880 columns]

# %%
# %%time
n_components = 0.70
res = get_pca_factors_model(returns_pd, n_components)
# Out:
# CPU times: user 9.15 s, sys: 817 ms, total: 9.97 s
# Wall time: 4.24 s

# %%
res['cleaned_corr']
# Out:
#       AACG
# AACG   1.0
