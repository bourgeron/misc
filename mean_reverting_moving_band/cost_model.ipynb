# %%
from utils import *

# %%
percentiles = [0.99, 0.90, 0.75, 0.50, 0.25, 0.10, 0.01]

# %%
market_data = load_and_prepare_market_data(
    path_market_data='prices_yf.parquet',
    start_date=init_date,
    volume_smoother=smoother_volumes,
    cost_transaction=0.0,
    cost_shorting=COST_SHORTING,
    cost_market_impact=market_impact_cost('volume_smoothed', 'volatility'),
).collect()
market_data.describe(percentiles=percentiles)
# Out:
# shape: (13, 12)
# ┌───────────┬───────────┬──────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ statistic ┆ date      ┆ symbol   ┆ price     ┆ … ┆ volume_sm ┆ cost_tran ┆ volatilit ┆ cost_mark │
# │ ---       ┆ ---       ┆ ---      ┆ ---       ┆   ┆ oothed    ┆ saction   ┆ y         ┆ et_impact │
# │ str       ┆ str       ┆ str      ┆ f64       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │           ┆           ┆          ┆           ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64       │
# ╞═══════════╪═══════════╪══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ count     ┆ 11098289  ┆ 11098289 ┆ 1.1098242 ┆ … ┆ 1.1081817 ┆ 1.1098289 ┆ 1.1098289 ┆ 1.0880285 │
# │           ┆           ┆          ┆ e7        ┆   ┆ e7        ┆ e7        ┆ e7        ┆ e7        │
# │ null_coun ┆ 0         ┆ 0        ┆ 47.0      ┆ … ┆ 16472.0   ┆ 0.0       ┆ 0.0       ┆ 218004.0  │
# │ t         ┆           ┆          ┆           ┆   ┆           ┆           ┆           ┆           │
# │ mean      ┆ 2015-06-2 ┆ null     ┆ 4.0150e10 ┆ … ┆ 4.1601e7  ┆ 0.0       ┆ 0.112915  ┆ 0.002084  │
# │           ┆ 1         ┆          ┆           ┆   ┆           ┆           ┆           ┆           │
# │ std       ┆ null      ┆ null     ┆ 4.6941e12 ┆ … ┆ 4.4957e8  ┆ 0.0       ┆ 1.583115  ┆ 0.154573  │
# │ min       ┆ 2000-01-0 ┆ AACG     ┆ 0.001     ┆ … ┆ 0.0       ┆ 0.0       ┆ 0.0       ┆ 9.0483e-9 │
# │           ┆ 3         ┆          ┆           ┆   ┆           ┆           ┆           ┆           │
# │ …         ┆ …         ┆ …        ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ 50%       ┆ 2016-12-2 ┆ null     ┆ 16.351    ┆ … ┆ 881538.23 ┆ 0.0       ┆ 0.03417   ┆ 0.000033  │
# │           ┆ 9         ┆          ┆           ┆   ┆ 9302      ┆           ┆           ┆           │
# │ 75%       ┆ 2021-06-0 ┆ null     ┆ 36.736912 ┆ … ┆ 7.7397e6  ┆ 0.0       ┆ 0.05257   ┆ 0.000126  │
# │           ┆ 4         ┆          ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 90%       ┆ 2023-03-1 ┆ null     ┆ 93.0      ┆ … ┆ 4.3853e7  ┆ 0.0       ┆ 0.082006  ┆ 0.000398  │
# │           ┆ 0         ┆          ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 99%       ┆ 2024-02-2 ┆ null     ┆ 18600.0   ┆ … ┆ 6.0934e8  ┆ 0.0       ┆ 0.520085  ┆ 0.005771  │
# │           ┆ 9         ┆          ┆           ┆   ┆           ┆           ┆           ┆           │
# │ max       ┆ 2024-04-0 ┆ ZYXI     ┆ 1.0410e15 ┆ … ┆ 6.6578e10 ┆ 0.0       ┆ 59.608116 ┆ 62.893911 │
# │           ┆ 9         ┆          ┆           ┆   ┆           ┆           ┆           ┆           │
# └───────────┴───────────┴──────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
market_data.select(pl.col([pl.Float32, pl.Float64]).is_nan()).sum()
# Out:
# shape: (1, 7)
# ┌───────┬────────┬───────────────┬─────────────────┬─────────────────┬────────────┬────────────────┐
# │ price ┆ volume ┆ cost_shorting ┆ volume_smoothed ┆ cost_transactio ┆ volatility ┆ cost_market_im │
# │ ---   ┆ ---    ┆ ---           ┆ ---             ┆ n               ┆ ---        ┆ pact           │
# │ u32   ┆ u32    ┆ u32           ┆ u32             ┆ ---             ┆ u32        ┆ ---            │
# │       ┆        ┆               ┆                 ┆ u32             ┆            ┆ u32            │
# ╞═══════╪════════╪═══════════════╪═════════════════╪═════════════════╪════════════╪════════════════╡
# │ 0     ┆ 0      ┆ 0             ┆ 0               ┆ 0               ┆ 0          ┆ 0              │
# └───────┴────────┴───────────────┴─────────────────┴─────────────────┴────────────┴────────────────┘

# %%
market_data.select(pl.col([pl.Float32, pl.Float64]).is_null()).sum()
# Out:
# shape: (1, 7)
# ┌───────┬────────┬───────────────┬─────────────────┬─────────────────┬────────────┬────────────────┐
# │ price ┆ volume ┆ cost_shorting ┆ volume_smoothed ┆ cost_transactio ┆ volatility ┆ cost_market_im │
# │ ---   ┆ ---    ┆ ---           ┆ ---             ┆ n               ┆ ---        ┆ pact           │
# │ u32   ┆ u32    ┆ u32           ┆ u32             ┆ ---             ┆ u32        ┆ ---            │
# │       ┆        ┆               ┆                 ┆ u32             ┆            ┆ u32            │
# ╞═══════╪════════╪═══════════════╪═════════════════╪═════════════════╪════════════╪════════════════╡
# │ 47    ┆ 47     ┆ 0             ┆ 16472           ┆ 0               ┆ 0          ┆ 218004         │
# └───────┴────────┴───────────────┴─────────────────┴─────────────────┴────────────┴────────────────┘

# %% [markdown]
# # Shorting cost

# %%
COST_SHORTING * 1e4
# Out:
# 0.1984126984126984

# %% [markdown]
# # Transaction cost

# %% [markdown]
# ## Check formula

# %%
def transaction_cost(smoothed_volume):
    params = {
        'log_coef': -0.175437,
        'const_coef': 4.169923,
        'mult_bias': 1.301015,
        'max': 90.0,
        'min': 0.1,
    }
    return (
        (params['const_coef'] + pl.col(smoothed_volume).log() * params['log_coef'])
        .exp()
        .mul(params['mult_bias'])
        .clip(params['min'], params['max'])
        .mul(1e-4)
    )

# %%
def transaction_cost_no_clip(smoothed_volume):
    params = {
        'log_coef': -0.175437,
        'const_coef': 4.169923,
        'mult_bias': 1.301015,
        'max': 90.0,
        'min': 0.1,
    }
    return (
        (params['const_coef'] + pl.col(smoothed_volume).log() * params['log_coef'])
        .exp()
        .mul(params['mult_bias'])
    )

# %%
col = 'volume'
data = np.logspace(0, 11, 10000)  # np.linspace(1, 1e11, 10000)
data = (
    pl.DataFrame(data, schema=['volume'])
    .with_columns(cost_transaction=transaction_cost_no_clip('volume'))
)
plot_ts(data, 'volume')
plot_ts(data, 'volume', logx=True)
plot_ts(data, 'volume', logy=True)
plot_ts(data, 'volume', loglog=True)

# %%
col = 'volume'
data = np.logspace(0, 5, 10000)  # np.linspace(1, 1e10, 10000)
data = (
    pl.DataFrame(data, schema=['volume'])
    .with_columns(cost_transaction=transaction_cost_no_clip('volume'))
)
plot_ts(data, 'volume')
plot_ts(data, 'volume', logx=True)
plot_ts(data, 'volume', logy=True)
plot_ts(data, 'volume', loglog=True)

# %%
market_data.select(cost_transaction=transaction_cost_no_clip('volume_smoothed')).describe(percentiles=percentiles)
# Out:
# shape: (13, 2)
# ┌────────────┬──────────────────┐
# │ statistic  ┆ cost_transaction │
# │ ---        ┆ ---              │
# │ str        ┆ f64              │
# ╞════════════╪══════════════════╡
# │ count      ┆ 1.1081817e7      │
# │ null_count ┆ 16472.0          │
# │ mean       ┆ inf              │
# │ std        ┆ NaN              │
# │ min        ┆ 1.062781         │
# │ …          ┆ …                │
# │ 50%        ┆ 7.62503          │
# │ 75%        ┆ 11.305107        │
# │ 90%        ┆ 16.264721        │
# │ 99%        ┆ inf              │
# │ max        ┆ inf              │
# └────────────┴──────────────────┘

# %%
market_data.select(cost_transaction=transaction_cost('volume_smoothed') * 1e4).describe(percentiles=percentiles)
# Out:
# shape: (13, 2)
# ┌────────────┬──────────────────┐
# │ statistic  ┆ cost_transaction │
# │ ---        ┆ ---              │
# │ str        ┆ f64              │
# ╞════════════╪══════════════════╡
# │ count      ┆ 1.1081817e7      │
# │ null_count ┆ 16472.0          │
# │ mean       ┆ 10.331137        │
# │ std        ┆ 12.095633        │
# │ min        ┆ 1.062781         │
# │ …          ┆ …                │
# │ 50%        ┆ 7.62503          │
# │ 75%        ┆ 11.305107        │
# │ 90%        ┆ 16.264721        │
# │ 99%        ┆ 90.0             │
# │ max        ┆ 90.0             │
# └────────────┴──────────────────┘

# %% [markdown]
# ## Check on data

# %%
(
    market_data
    .with_columns(pl.col('volume_smoothed').log() / np.log(10))
    .select(not_finite_floats_to_none('volume_smoothed'))
    .to_pandas().hist(bins=1000)
)
# Out:
# array([[<Axes: title={'center': 'volume_smoothed'}>]], dtype=object)

# %%
transaction_costs = (
    market_data
    .select(cost_transaction=transaction_cost('volume_smoothed') * 1e4)
)
(
    transaction_costs
    .to_pandas()
    .hist(bins=1000, log=True, density=True)
)
# Out:
# array([[<Axes: title={'center': 'cost_transaction'}>]], dtype=object)

# %%
# scatter_plot = (
#     market_data
#     .select([
#         (transaction_cost('volume_smoothed') * 1e4).alias('cost_transaction'),
#         'volume_smoothed',
#     ])
#     .select(pl.all().log())
# )
# scatter_plot.to_pandas().plot.scatter('cost_transaction', 'volume_smoothed')

# %% [markdown]
# # Market impact

# %%
market_impact_costs = (
    market_data
    .select(cost_market_impact=pl.col('cost_market_impact') * 1e4)
)

# %%
(
    market_impact_costs
    .to_pandas()
    .hist(bins=1000, log=True, density=True)
)
# Out:
# array([[<Axes: title={'center': 'cost_market_impact'}>]], dtype=object)

# %%
(
    market_impact_costs
    .to_pandas()
    .clip(0, 5)
    .hist(bins=1000, log=True, density=True)
)
# Out:
# array([[<Axes: title={'center': 'cost_market_impact'}>]], dtype=object)

# %%
market_impact_costs.describe(percentiles=percentiles)
# Out:
# shape: (13, 2)
# ┌────────────┬────────────────────┐
# │ statistic  ┆ cost_market_impact │
# │ ---        ┆ ---                │
# │ str        ┆ f64                │
# ╞════════════╪════════════════════╡
# │ count      ┆ 1.0880285e7        │
# │ null_count ┆ 218004.0           │
# │ mean       ┆ 20.837905          │
# │ std        ┆ 1545.733464        │
# │ min        ┆ 0.00009            │
# │ …          ┆ …                  │
# │ 50%        ┆ 0.327841           │
# │ 75%        ┆ 1.259329           │
# │ 90%        ┆ 3.975728           │
# │ 99%        ┆ 57.710389          │
# │ max        ┆ 628939.105121      │
# └────────────┴────────────────────┘
